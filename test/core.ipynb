# %%
import ziamath as zm
font = None

# %%
# SVG2 mode (not supported by all browsers/viewers)
zm.config.svg2 = True
svg = zm.Math.fromlatextext('This is math: $x^2 + y^2$', font=font)
assert 'symbol' in svg.svg()
svg

# %%
# SVG1.x mode doesn't use <symbol> and <use> to place glyphs
zm.config.svg2 = False
svg = zm.Math.fromlatextext('This is math: $x^2 + y^2$', font=font)
assert 'symbol' not in svg.svg()
svg

# %%
zm.config.svg2 = True

# %%
zm.config.minsizefraction = .5
zm.Math.fromlatex('a^{2^{2^{2^2}}}', font=font)

# %%
zm.config.minsizefraction = .1
zm.Math.fromlatex('a^{2^{2^{2^2}}}', font=font)

# %%
# SVG precision
zm.config.precision = 3
zm.Math.fromlatex('a', font=font).svg()
# Out:
# '<svg width="14.144" height="13.784" xmlns="http://www.w3.org/2000/svg" viewBox="0.176 -12.496 14.144 13.784"><symbol id="STIXTwoMathRegular_3326" width="6.468" height="51.216" viewBox="0 -31.524 6.468 51.216"><path d="M 6.024 -5.664 L 6.024 -5.664 L 5.16 -1.416 Q 5.16 -1.416 5.13 -1.26 Q 5.1 -1.104 5.1 -0.972 Q 5.1 -0.852 5.148 -0.786 Q 5.196 -0.72 5.34 -0.72 Q 5.532 -0.72 5.706 -0.834 Q 5.88 -0.948 6.018 -1.098 Q 6.156 -1.248 6.228 -1.344 L 6.468 -1.164 Q 6.096 -0.588 5.688 -0.234 Q 5.28 0.12 4.74 0.12 Q 4.068 0.12 4.068 -0.456 Q 4.068 -0.588 4.098 -0.726 Q 4.128 -0.864 4.152 -1.02 L 4.068 -1.02 Q 3.12 0.144 2.064 0.144 Q 1.416 0.144 1.002 -0.36 Q 0.588 -0.864 0.588 -1.908 Q 0.588 -2.724 0.846 -3.426 Q 1.104 -4.128 1.536 -4.65 Q 1.968 -5.172 2.52 -5.46 Q 3.072 -5.748 3.66 -5.748 Q 4.14 -5.748 4.428 -5.568 Q 4.716 -5.388 4.908 -5.112 L 4.956 -5.112 L 5.388 -5.664 Z M 4.668 -4.128 L 4.668 -4.128 Q 4.668 -4.608 4.398 -4.95 Q 4.128 -5.292 3.624 -5.292 Q 3.18 -5.292 2.814 -5.01 Q 2.448 -4.728 2.19 -4.26 Q 1.932 -3.792 1.794 -3.21 Q 1.656 -2.628 1.656 -2.028 Q 1.656 -1.2 1.914 -0.924 Q 2.172 -0.648 2.616 -0.648 Q 3.216 -0.648 3.624 -1.026 Q 4.032 -1.404 4.296 -2.172 Q 4.416 -2.532 4.5 -2.91 Q 4.584 -3.288 4.626 -3.618 Q 4.668 -3.948 4.668 -4.128 Z " /></symbol><use href="#STIXTwoMathRegular_3326" transform="translate(1 -63.048) scale(2)" fill="black" /></svg>'

# %%
# SVG precision
zm.config.precision = 1
zm.Math.fromlatex('a', font=font).svg()
# Out:
# '<svg width="14.1" height="13.8" xmlns="http://www.w3.org/2000/svg" viewBox="0.2 -12.5 14.1 13.8"><symbol id="STIXTwoMathRegular_3326" width="6.5" height="51.2" viewBox="0 -31.5 6.5 51.2"><path d="M 6 -5.7 L 6 -5.7 L 5.2 -1.4 Q 5.2 -1.4 5.1 -1.3 Q 5.1 -1.1 5.1 -1 Q 5.1 -0.9 5.1 -0.8 Q 5.2 -0.7 5.3 -0.7 Q 5.5 -0.7 5.7 -0.8 Q 5.9 -0.9 6 -1.1 Q 6.2 -1.2 6.2 -1.3 L 6.5 -1.2 Q 6.1 -0.6 5.7 -0.2 Q 5.3 0.1 4.7 0.1 Q 4.1 0.1 4.1 -0.5 Q 4.1 -0.6 4.1 -0.7 Q 4.1 -0.9 4.2 -1 L 4.1 -1 Q 3.1 0.1 2.1 0.1 Q 1.4 0.1 1 -0.4 Q 0.6 -0.9 0.6 -1.9 Q 0.6 -2.7 0.8 -3.4 Q 1.1 -4.1 1.5 -4.7 Q 2 -5.2 2.5 -5.5 Q 3.1 -5.7 3.7 -5.7 Q 4.1 -5.7 4.4 -5.6 Q 4.7 -5.4 4.9 -5.1 L 5 -5.1 L 5.4 -5.7 Z M 4.7 -4.1 L 4.7 -4.1 Q 4.7 -4.6 4.4 -5 Q 4.1 -5.3 3.6 -5.3 Q 3.2 -5.3 2.8 -5 Q 2.4 -4.7 2.2 -4.3 Q 1.9 -3.8 1.8 -3.2 Q 1.7 -2.6 1.7 -2 Q 1.7 -1.2 1.9 -0.9 Q 2.2 -0.6 2.6 -0.6 Q 3.2 -0.6 3.6 -1 Q 4 -1.4 4.3 -2.2 Q 4.4 -2.5 4.5 -2.9 Q 4.6 -3.3 4.6 -3.6 Q 4.7 -3.9 4.7 -4.1 Z " /></symbol><use href="#STIXTwoMathRegular_3326" transform="translate(1 -63) scale(2)" fill="black" /></svg>'

# %%
zm.Latex(r'1 + \blah(x)')   # blah isn't a function

# %%
zm.declareoperator(r'\blah')
zm.Latex(r'1 + \blah(x)')   # Now it is.

# %%
# ziamath declares a few trig alternates that latex2mathml doesn't have
zm.Latex(r'1 + \tg\theta + \ctg\theta + \arctg\theta + \arcctg\theta')

# %%
# Decimal separator only affects commas between digits
zm.config.decimal_separator = '.'
zm.Latex('1,23 + 12\,3 + (x, y, z)')

# %%
zm.config.decimal_separator = ','
zm.Latex('1,23 + 12\,3 + (x, y, z)')

# %%
zm.config.debug = True

# %%
import ziafont as zf
import xml.etree.ElementTree as ET
from IPython.display import SVG

# %%
svg = ET.Element('svg')
svg.attrib['xmlns'] = 'http://www.w3.org/2000/svg'
svg.attrib['xmlns:xlink'] = 'http://www.w3.org/1999/xlink'
svg.attrib['width'] = '300'
svg.attrib['height'] = '200'
svg.attrib['viewBox'] = '0 0 300 200'

zm.Text('ABC', color='orange').drawon(svg, 100, 100)
zm.Math.fromlatex('a^2', color='green').drawon(svg, 100, 180)
zm.Math.fromlatextext('Hi $n^2$', color='maroon').drawon(svg, 200, 100)
zf.Text('What', color='yellow').drawon(svg, 180, 180)
SVG(ET.tostring(svg))

# %%
font = zm.zmath.loadedfonts['default']
paren = font.glyph('⏞').index
font.math.variant(paren, 1000, vert=False)

# %%
font.math.variant(paren, 3000, vert=False)

# %%
font.math.variant(paren, 8000, vert=False)

# %%
testchrs = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ abcdefghijklmnopqrstuvwxyz ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 0123456789'
print(zm.styledstr('Regular ' + testchrs, zm.styles.MathVariant('serif', italic=False, bold=False)))
print(zm.styledstr('Serif Italic ' + testchrs, zm.styles.MathVariant('serif', italic=True, bold=False)))
print(zm.styledstr('Serif Bold ' + testchrs, zm.styles.MathVariant('serif', italic=False, bold=True)))
print(zm.styledstr('Serif Bold Italic ' + testchrs, zm.styles.MathVariant('serif', italic=True, bold=True)))
print(zm.styledstr('Sans ' + testchrs, zm.styles.MathVariant('sans', italic=False, bold=False)))
print(zm.styledstr('Sans Italic ' + testchrs, zm.styles.MathVariant('sans', italic=True, bold=False)))
print(zm.styledstr('Sans Bold ' + testchrs, zm.styles.MathVariant('sans', italic=False, bold=True)))
print(zm.styledstr('Sans Bold Italic ' + testchrs, zm.styles.MathVariant('sans', italic=True, bold=True)))
print(zm.styledstr('Script ' + testchrs, zm.styles.MathVariant('script', italic=False, bold=False)))
print(zm.styledstr('Script Bold ' + testchrs, zm.styles.MathVariant('script', italic=False, bold=True)))
print(zm.styledstr('Fraktur ' + testchrs, zm.styles.MathVariant('fraktur', italic=False, bold=False)))
print(zm.styledstr('Fraktur Bold ' + testchrs, zm.styles.MathVariant('fraktur', italic=False, bold=True)))
print(zm.styledstr('Mono ' + testchrs, zm.styles.MathVariant('mono', italic=False, bold=False)))
print(zm.styledstr('Mono Bold ' + testchrs, zm.styles.MathVariant('mono', italic=False, bold=True)))
# Out:
# Regular ABCDEFGHIJKLMNOPQRSTUVWXYZ abcdefghijklmnopqrstuvwxyz ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 0123456789
# 𝑆𝑒𝑟𝑖𝑓 𝐼𝑡𝑎𝑙𝑖𝑐 𝐴𝐵𝐶𝐷𝐸𝐹𝐺𝐻𝐼𝐽𝐾𝐿𝑀𝑁𝑂𝑃𝑄𝑅𝑆𝑇𝑈𝑉𝑊𝑋𝑌𝑍 𝑎𝑏𝑐𝑑𝑒𝑓𝑔ℎ𝑖𝑗𝑘𝑙𝑚𝑛𝑜𝑝𝑞𝑟𝑠𝑡𝑢𝑣𝑤𝑥𝑦𝑧 𝛢𝛣𝛤𝛥𝛦𝛧𝛨𝛩𝛪𝛫𝛬𝛭𝛮𝛯𝛰𝛱𝛲𝛳𝛴𝛵𝛶𝛷𝛸𝛹𝛺𝛻 𝛼𝛽𝛾𝛿𝜀𝜁𝜂𝜃𝜄𝜅𝜆𝜇𝜈𝜉𝜊𝜋𝜌𝜍𝜎𝜏𝜐𝜑𝜒𝜓𝜔𝜕𝜖𝜗𝜘𝜙𝜚𝜛 0123456789
# 𝐒𝐞𝐫𝐢𝐟 𝐁𝐨𝐥𝐝 𝐀𝐁𝐂𝐃𝐄𝐅𝐆𝐇𝐈𝐉𝐊𝐋𝐌𝐍𝐎𝐏𝐐𝐑𝐒𝐓𝐔𝐕𝐖𝐗𝐘𝐙 𝐚𝐛𝐜𝐝𝐞𝐟𝐠𝐡𝐢𝐣𝐤𝐥𝐦𝐧𝐨𝐩𝐪𝐫𝐬𝐭𝐮𝐯𝐰𝐱𝐲𝐳 𝚨𝚩𝚪𝚫𝚬𝚭𝚮𝚯𝚰𝚱𝚲𝚳𝚴𝚵𝚶𝚷𝚸𝚹𝚺𝚻𝚼𝚽𝚾𝚿𝛀𝛁 𝛂𝛃𝛄𝛅𝛆𝛇𝛈𝛉𝛊𝛋𝛌𝛍𝛎𝛏𝛐𝛑𝛒𝛓𝛔𝛕𝛖𝛗𝛘𝛙𝛚𝛛𝛜𝛝𝛞𝛟𝛠𝛡 𝟎𝟏𝟐𝟑𝟒𝟓𝟔𝟕𝟖𝟗
# 𝑺𝒆𝒓𝒊𝒇 𝑩𝒐𝒍𝒅 𝑰𝒕𝒂𝒍𝒊𝒄 𝑨𝑩𝑪𝑫𝑬𝑭𝑮𝑯𝑰𝑱𝑲𝑳𝑴𝑵𝑶𝑷𝑸𝑹𝑺𝑻𝑼𝑽𝑾𝑿𝒀𝒁 𝒂𝒃𝒄𝒅𝒆𝒇𝒈𝒉𝒊𝒋𝒌𝒍𝒎𝒏𝒐𝒑𝒒𝒓𝒔𝒕𝒖𝒗𝒘𝒙𝒚𝒛 𝜜𝜝𝜞𝜟𝜠𝜡𝜢𝜣𝜤𝜥𝜦𝜧𝜨𝜩𝜪𝜫𝜬𝜭𝜮𝜯𝜰𝜱𝜲𝜳𝜴𝜵 𝜶𝜷𝜸𝜹𝜺𝜻𝜼𝜽𝜾𝜿𝝀𝝁𝝂𝝃𝝄𝝅𝝆𝝇𝝈𝝉𝝊𝝋𝝌𝝍𝝎𝝏𝝐𝝑𝝒𝝓𝝔𝝕 0123456789
# 𝖲𝖺𝗇𝗌 𝖠𝖡𝖢𝖣𝖤𝖥𝖦𝖧𝖨𝖩𝖪𝖫𝖬𝖭𝖮𝖯𝖰𝖱𝖲𝖳𝖴𝖵𝖶𝖷𝖸𝖹 𝖺𝖻𝖼𝖽𝖾𝖿𝗀𝗁𝗂𝗃𝗄𝗅𝗆𝗇𝗈𝗉𝗊𝗋𝗌𝗍𝗎𝗏𝗐𝗑𝗒𝗓 ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 𝟢𝟣𝟤𝟥𝟦𝟧𝟨𝟩𝟪𝟫
# 𝘚𝘢𝘯𝘴 𝘐𝘵𝘢𝘭𝘪𝘤 𝘈𝘉𝘊𝘋𝘌𝘍𝘎𝘏𝘐𝘑𝘒𝘓𝘔𝘕𝘖𝘗𝘘𝘙𝘚𝘛𝘜𝘝𝘞𝘟𝘠𝘡 𝘢𝘣𝘤𝘥𝘦𝘧𝘨𝘩𝘪𝘫𝘬𝘭𝘮𝘯𝘰𝘱𝘲𝘳𝘴𝘵𝘶𝘷𝘸𝘹𝘺𝘻 ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 𝟢𝟣𝟤𝟥𝟦𝟧𝟨𝟩𝟪𝟫
# 𝗦𝗮𝗻𝘀 𝗕𝗼𝗹𝗱 𝗔𝗕𝗖𝗗𝗘𝗙𝗚𝗛𝗜𝗝𝗞𝗟𝗠𝗡𝗢𝗣𝗤𝗥𝗦𝗧𝗨𝗩𝗪𝗫𝗬𝗭 𝗮𝗯𝗰𝗱𝗲𝗳𝗴𝗵𝗶𝗷𝗸𝗹𝗺𝗻𝗼𝗽𝗾𝗿𝘀𝘁𝘂𝘃𝘄𝘅𝘆𝘇 𝝖𝝗𝝘𝝙𝝚𝝛𝝜𝝝𝝞𝝟𝝠𝝡𝝢𝝣𝝤𝝥𝝦𝝧𝝨𝝩𝝪𝝫𝝬𝝭𝝮𝝯 𝝰𝝱𝝲𝝳𝝴𝝵𝝶𝝷𝝸𝝹𝝺𝝻𝝼𝝽𝝾𝝿𝞀𝞁𝞂𝞃𝞄𝞅𝞆𝞇𝞈𝞉𝞊𝞋𝞌𝞍𝞎𝞏 𝟬𝟭𝟮𝟯𝟰𝟱𝟲𝟳𝟴𝟵
# 𝙎𝙖𝙣𝙨 𝘽𝙤𝙡𝙙 𝙄𝙩𝙖𝙡𝙞𝙘 𝘼𝘽𝘾𝘿𝙀𝙁𝙂𝙃𝙄𝙅𝙆𝙇𝙈𝙉𝙊𝙋𝙌𝙍𝙎𝙏𝙐𝙑𝙒𝙓𝙔𝙕 𝙖𝙗𝙘𝙙𝙚𝙛𝙜𝙝𝙞𝙟𝙠𝙡𝙢𝙣𝙤𝙥𝙦𝙧𝙨𝙩𝙪𝙫𝙬𝙭𝙮𝙯 𝞐𝞑𝞒𝞓𝞔𝞕𝞖𝞗𝞘𝞙𝞚𝞛𝞜𝞝𝞞𝞟𝞠𝞡𝞢𝞣𝞤𝞥𝞦𝞧𝞨𝞩 𝞪𝞫𝞬𝞭𝞮𝞯𝞰𝞱𝞲𝞳𝞴𝞵𝞶𝞷𝞸𝞹𝞺𝞻𝞼𝞽𝞾𝞿𝟀𝟁𝟂𝟃𝟄𝟅𝟆𝟇𝟈𝟉 𝟢𝟣𝟤𝟥𝟦𝟧𝟨𝟩𝟪𝟫
# 𝒮𝒸𝓇𝒾𝓅𝓉 𝒜ℬ𝒞𝒟ℰℱ𝒢ℋℐ𝒥𝒦ℒℳ𝒩𝒪𝒫𝒬ℛ𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵 𝒶𝒷𝒸𝒹ℯ𝒻ℊ𝒽𝒾𝒿𝓀𝓁𝓂𝓃ℴ𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏 ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 0123456789
# 𝒮𝒸𝓇𝒾𝓅𝓉 ℬℴ𝓁𝒹 𝒜ℬ𝒞𝒟ℰℱ𝒢ℋℐ𝒥𝒦ℒℳ𝒩𝒪𝒫𝒬ℛ𝒮𝒯𝒰𝒱𝒲𝒳𝒴𝒵 𝒶𝒷𝒸𝒹ℯ𝒻ℊ𝒽𝒾𝒿𝓀𝓁𝓂𝓃ℴ𝓅𝓆𝓇𝓈𝓉𝓊𝓋𝓌𝓍𝓎𝓏 𝚨𝚩𝚪𝚫𝚬𝚭𝚮𝚯𝚰𝚱𝚲𝚳𝚴𝚵𝚶𝚷𝚸𝚹𝚺𝚻𝚼𝚽𝚾𝚿𝛀𝛁 𝛂𝛃𝛄𝛅𝛆𝛇𝛈𝛉𝛊𝛋𝛌𝛍𝛎𝛏𝛐𝛑𝛒𝛓𝛔𝛕𝛖𝛗𝛘𝛙𝛚𝛛𝛜𝛝𝛞𝛟𝛠𝛡 𝟎𝟏𝟐𝟑𝟒𝟓𝟔𝟕𝟖𝟗
# 𝔉𝔯𝔞𝔨𝔱𝔲𝔯 𝔄𝔅ℭ𝔇𝔈𝔉𝔊ℌℑ𝔍𝔎𝔏𝔐𝔑𝔒𝔓𝔔ℜ𝔖𝔗𝔘𝔙𝔚𝔛𝔜ℨ 𝔞𝔟𝔠𝔡𝔢𝔣𝔤𝔥𝔦𝔧𝔨𝔩𝔪𝔫𝔬𝔭𝔮𝔯𝔰𝔱𝔲𝔳𝔴𝔵𝔶𝔷 ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 0123456789
# 𝕱𝖗𝖆𝖐𝖙𝖚𝖗 𝕭𝖔𝖑𝖉 𝕬𝕭𝕮𝕯𝕰𝕱𝕲𝕳𝕴𝕵𝕶𝕷𝕸𝕹𝕺𝕻𝕼𝕽𝕾𝕿𝖀𝖁𝖂𝖃𝖄𝖅 𝖆𝖇𝖈𝖉𝖊𝖋𝖌𝖍𝖎𝖏𝖐𝖑𝖒𝖓𝖔𝖕𝖖𝖗𝖘𝖙𝖚𝖛𝖜𝖝𝖞𝖟 𝚨𝚩𝚪𝚫𝚬𝚭𝚮𝚯𝚰𝚱𝚲𝚳𝚴𝚵𝚶𝚷𝚸𝚹𝚺𝚻𝚼𝚽𝚾𝚿𝛀𝛁 𝛂𝛃𝛄𝛅𝛆𝛇𝛈𝛉𝛊𝛋𝛌𝛍𝛎𝛏𝛐𝛑𝛒𝛓𝛔𝛕𝛖𝛗𝛘𝛙𝛚𝛛𝛜𝛝𝛞𝛟𝛠𝛡 𝟎𝟏𝟐𝟑𝟒𝟓𝟔𝟕𝟖𝟗
# 𝙼𝚘𝚗𝚘 𝙰𝙱𝙲𝙳𝙴𝙵𝙶𝙷𝙸𝙹𝙺𝙻𝙼𝙽𝙾𝙿𝚀𝚁𝚂𝚃𝚄𝚅𝚆𝚇𝚈𝚉 𝚊𝚋𝚌𝚍𝚎𝚏𝚐𝚑𝚒𝚓𝚔𝚕𝚖𝚗𝚘𝚙𝚚𝚛𝚜𝚝𝚞𝚟𝚠𝚡𝚢𝚣 ΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡϴΣΤΥΦΧΨΩ∇ αβγδεζηθικλμνξοπρςστυφχψω∂ϵϑϰϕϱϖ 𝟶𝟷𝟸𝟹𝟺𝟻𝟼𝟽𝟾𝟿
# 𝙼𝚘𝚗𝚘 𝙱𝚘𝚕𝚍 𝙰𝙱𝙲𝙳𝙴𝙵𝙶𝙷𝙸𝙹𝙺𝙻𝙼𝙽𝙾𝙿𝚀𝚁𝚂𝚃𝚄𝚅𝚆𝚇𝚈𝚉 𝚊𝚋𝚌𝚍𝚎𝚏𝚐𝚑𝚒𝚓𝚔𝚕𝚖𝚗𝚘𝚙𝚚𝚛𝚜𝚝𝚞𝚟𝚠𝚡𝚢𝚣 𝚨𝚩𝚪𝚫𝚬𝚭𝚮𝚯𝚰𝚱𝚲𝚳𝚴𝚵𝚶𝚷𝚸𝚹𝚺𝚻𝚼𝚽𝚾𝚿𝛀𝛁 𝛂𝛃𝛄𝛅𝛆𝛇𝛈𝛉𝛊𝛋𝛌𝛍𝛎𝛏𝛐𝛑𝛒𝛓𝛔𝛕𝛖𝛗𝛘𝛙𝛚𝛛𝛜𝛝𝛞𝛟𝛠𝛡 𝟶𝟷𝟸𝟹𝟺𝟻𝟼𝟽𝟾𝟿
