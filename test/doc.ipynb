# %%
import ziamath as zm

# %%
zm.Math('''<mrow>
  <mi> y </mi>
  <mo> = </mo>
  <mi> f </mi>
  <mo> &ApplyFunction; </mo>
  <mrow>
    <mo> ( </mo>
      <mi> x </mi>
    <mo> ) </mo>
  </mrow>
</mrow>''')

# %%
zm.Math.fromlatex(r'c = \pm \sqrt{a^2 + b^2}')
