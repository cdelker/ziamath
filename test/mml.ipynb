# %% [markdown]
# ## Selected examples from MathML Specification
#
# https://www.w3.org/TR/MathML2/chapter3.html#presm.malign

# %%
import ziamath as zm
font = None

# %%
zm.Math('''<mrow>
  <mi> x </mi>
  <mo> + </mo>
  <mrow>
    <mi> a </mi>
    <mo> / </mo>
    <mi> b </mi>
  </mrow>
</mrow>''', font=font)

# %%
zm.Math('''<mrow>
  <mi> sin </mi>
  <mo> &ApplyFunction; </mo>
  <mi> x </mi>
</mrow>''', font=font)

# %%
zm.Math('''<mrow>
  <mo> ( </mo>
  <mrow>
    <mi> a </mi>
    <mo> + </mo>
    <mi> b </mi>
  </mrow>
  <mo> ) </mo>
</mrow>''', font=font)

# %%
zm.Math('''
<mfenced>
  <mrow>
    <mi> a </mi>
    <mo> + </mo>
    <mi> b </mi>
  </mrow>
</mfenced>
''', font=font)

# %%
zm.Math('''<mrow>
  <mi> f </mi>
  <mo> &ApplyFunction; </mo>
  <mrow>
    <mo> ( </mo>
    <mrow>
      <mi> x </mi>
      <mo> , </mo>
      <mi> y </mi>
    </mrow>
    <mo> ) </mo>
  </mrow>
</mrow>''', font=font)

# %%
zm.Math('''
<mrow>
  <mi> f </mi>
  <mo> &ApplyFunction; </mo>
  <mfenced>
    <mi> x </mi>
    <mi> y </mi>
  </mfenced>
</mrow>
''', font=font)

# %%
zm.Math('''<mrow>
  <mi> f </mi>
  <mo> &ApplyFunction; </mo>
  <mrow>
    <mo> ( </mo>
    <mi> x </mi>
    <mo> ) </mo>
  </mrow>
</mrow>''', font=font)

# %%
zm.Math('''<msub>
  <mi> m </mi>
  <mrow>
    <mn> 1 </mn>
    <mo> &InvisibleComma; </mo>
    <mn> 2 </mn>
  </mrow>
</msub>
''', font=font)

# %%
zm.Math('''<mrow>
  <mo> [ </mo>
  <mrow>
    <mn> 0 </mn>
    <mo> , </mo>
    <mn> 1 </mn>
  </mrow>
  <mo> ) </mo>
</mrow>''', font=font)

# %%
zm.Math('''
<mfenced open="[">
  <mn> 0 </mn>
  <mn> 1 </mn>
</mfenced>''', font=font)

# %%
zm.Math('''<mrow>
  <mrow>
    <mn> 2 </mn>
    <mo> &InvisibleTimes; </mo>
    <mi> x </mi>
  </mrow>
  <mo> + </mo>
  <mi> y </mi>
  <mo> - </mo>
  <mi> z </mi>
</mrow>''', font=font)

# %%
zm.Math('''<mrow>
  <mo> ( </mo>
  <mrow>
    <mi> x </mi>
    <mo> , </mo>
    <mi> y </mi>
  </mrow>
  <mo> ) </mo>
</mrow>''', font=font)

# %%
zm.Math('''<mfrac>
  <mrow>
    <mi> x </mi>
    <mo> + </mo>
    <mi> y </mi>
    <mo> + </mo>
    <mi> z </mi>
  </mrow>
  <mrow>
    <mi> x </mi>
    <mphantom>
      <mo form="infix"> + </mo>
      <mi> y </mi>
    </mphantom>
    <mo> + </mo>
    <mi> z </mi>
  </mrow>
</mfrac>''', font=font)

# %%
zm.Math('''<mrow>
  <msubsup>
    <mo> &int; </mo>
    <mn> 0 </mn>
    <mn> 1 </mn>
  </msubsup>
  <mrow>
    <msup>
      <mi> &ExponentialE; </mi>
      <mi> x </mi>
    </msup>
    <mo> &InvisibleTimes; </mo>
    <mrow>
      <mo> &DifferentialD; </mo>
      <mi> x </mi>
    </mrow>
  </mrow>
</mrow>''', font=font)

# %%
zm.Math('''<mrow>
  <mo> ( </mo>
  <mtable>
    <mtr>
      <mtd> <mn>1</mn> </mtd>
      <mtd> <mn>0</mn> </mtd>
      <mtd> <mn>0</mn> </mtd>
    </mtr>
    <mtr>
      <mtd> <mn>0</mn> </mtd>
      <mtd> <mn>1</mn> </mtd>
      <mtd> <mn>0</mn> </mtd>
    </mtr>
    <mtr>
      <mtd> <mn>0</mn> </mtd>
      <mtd> <mn>0</mn> </mtd>
      <mtd> <mn>1</mn> </mtd>
    </mtr>
  </mtable>
  <mo> ) </mo>
</mrow>''', font=font)

# %% [markdown]
# ### menclose notations

# %%
zm.Math('''
<menclose notation="longdiv">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="actuarial">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="box">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="roundedbox">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="circle">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="left">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="right">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="top">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="bottom">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="updiagonalstrike">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="downdiagonalstrike">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="verticalstrike">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="horizontalstrike">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="madruwb">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<math>
<mfrac>
    <mrow><mn>1</mn></mrow>
    <mrow>
        <msup><mi>a</mi><mn>2</mn></msup>
        <mo>+</mo>
        <menclose notation="updiagonalstrike downdiagonalstrike">
            <msup><mi>b</mi><mn>2</mn></msup>
        </menclose>
    </mrow>
</mfrac>
</math>
''', font=font)

# %%
zm.Math('''
<menclose notation="phasorangle">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="box downdiagonalstrike updiagonalstrike">
    <msup><mi>a</mi><mn>2</mn></msup>
    <mo>+</mo>
    <msup><mi>b</mi><mn>2</mn></msup>
</menclose>
''', font=font)

# %%
zm.Math('''
<menclose notation="roundedbox downdiagonalstrike">
    <mfrac>
        <mrow>
            <msup><mi>a</mi><mn>2</mn></msup>
            <mo>+</mo>
            <msup><mi>b</mi><mn>2</mn></msup>
        </mrow>
        <mrow>
            <mi>c</mi>
            <mo>+</mo>
            <mn>1</mn>
        </mrow>
    </mfrac>
</menclose>
''', font=font)
